# %%
from manimlib import *
from manimlib.mobject.svg.text_mobject import Text

# %%
# %%manimlib latex_example LaTeXExample
# class LaTeXExample(Scene):
#     def construct(self):
#         text = Text("Hello World")
#         self.add(text)
